# %% [markdown]
# ## Loading the Datasets
#
# #### Import libraries

# %%
import os
import glob
import pandas as pd

# %%
path = os.getcwd()

# %%
files = glob.glob(os.path.join(path,"*.csv"))

# %%
frame = []

# %%
for file in files:
    frame.append(pd.read_csv(file))

# %%
df = pd.concat(frame)

# %% [markdown]
# ## Data Exploration
#
# #### Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# ...

# %% [markdown]
# ##### From the statistical summary above, i can derive the number(count) of values, mean, standard deviation, minimum, maximum values of all the attributes. I can also derive the 25th, 50th and 75th percentile for all the given attributes.

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 323       False   False  False          False   False         False
# 324       False   False  False          False   False         False
# 325       False   False  False          False   False         False
# 326       False   False  False          False   False         False
# 327       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
df.notna()
# Out:
#      Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0          True    True  True           True    True          True
# 1          True    True  True           True    True          True
# 2          True    True  True           True    True          True
# 3          True    True  True           True    True          True
# 4          True    True  True           True    True          True
# ..          ...     ...   ...            ...     ...           ...
# 323        True    True  True           True    True          True
# 324        True    True  True           True    True          True
# 325        True    True  True           True    True          True
# 326        True    True  True           True    True          True
# 327        True    True  True           True    True          True
#
#      Unit price  Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# 0          True      True    True   True  True  True     True  True
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.notna().sum()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 327
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ## Dealing with DateTime Features

# %%
import datetime as dt

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df['Time']= pd.to_datetime(df['Time'])

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %% [markdown]
# #### Extract features from Date and Time

# %%
df['Day'] = df['Date'].dt.day

# %%
df['Month'] = df['Date'].dt.month

# %%
df['Year'] = df['Date'].dt.year

# %%
df['Hour'] = df['Time'].dt.hour

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total  ...                Time Payment  \
# 0     19742.4         3   2961.36   62188.56  ... 2023-02-02 13:27:00    Card
# 1      5212.8         4   1042.56   21893.76  ... 2023-02-02 18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12  ... 2023-02-02 17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96  ... 2023-02-02 16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80  ... 2023-02-02 15:30:00    Epay
#
# ...

# %%
df.Hour.nunique()
# Out:
# 11

# %%
df.Hour.unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %% [markdown]
# ### Unique Values in Columns

# %%
categorical_columns =[col for col in df.columns if df[col].dtype=="object"]

# %% [markdown]
# #### Below, i created a dataset(cat_cols) of the categorical columns

# %%
cat_cols = df.select_dtypes(exclude='number')

# %%
cat_cols
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    692-92-5582      B          Abuja        Member  Female
# 1    351-62-0822      B          Abuja        Member  Female
# 2    529-56-3974      B          Abuja        Member    Male
# 3    299-46-1805      B          Abuja        Member  Female
# 4    319-50-3348      B          Abuja        Normal  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line       Date                Time Payment
# 0        Food and beverages 2019-02-20 2023-02-02 13:27:00    Card
# 1       Fashion accessories 2019-02-06 2023-02-02 18:07:00    Epay
# ...

# %%
df['Invoice ID'].unique().tolist()
# Out:
# ['692-92-5582',
#  '351-62-0822',
#  '529-56-3974',
#  '299-46-1805',
#  '319-50-3348',
#  '371-85-5789',
#  '273-16-6619',
#  '649-29-6775',
#  '145-94-9061',
#  '871-79-8483',
#  '149-71-6266',
#  '640-49-2076',
#  '777-82-7220',
#  '280-35-5823',
#  '354-25-5821',
#  '132-32-9879',
#  '370-41-7321',
#  '727-46-3608',
#  '669-54-1719',
#  '616-24-2851',
#  '242-55-6721',
#  '347-34-2234',
#  '853-23-2453',
#  '109-28-2512',
#  '510-95-6347',
#  '847-38-7188',
#  '318-68-5053',
#  '152-08-9985',
#  '766-85-7061',
#  '733-01-9107',
#  '716-39-1409',
#  '479-26-8945',
#  '227-78-1148',
#  '291-32-1427',
#  '659-65-8956',
#  '378-24-2715',
#  '219-22-9386',
#  '268-27-6179',
#  '549-84-7482',
#  '191-10-6171',
#  '695-51-0018',
#  '590-83-4591',
#  '241-72-9525',
#  '262-47-2794',
#  '608-96-3517',
#  '279-74-2924',
#  '307-85-2293',
#  '743-04-1105',
#  '423-57-2993',
#  '548-46-9322',
#  '505-02-0892',
#  '316-55-4634',
#  '608-27-6295',
#  '414-12-7047',
#  '895-66-0685',
# ...

# %%
print("Total number of unique values in the Invoice ID column: {}".format(len(df['Invoice ID'].unique().tolist())))
# Out:
# Total number of unique values in the Invoice ID column: 1000

# %%
df['City'].unique().tolist()
# Out:
# ['Abuja', 'Lagos', 'Port Harcourt']

# %%
print("Total number of unique values in the City column: {}".format(len(df['City'].unique().tolist())))
# Out:
# Total number of unique values in the City column: 3

# %%
df['Customer type'].unique().tolist()
# Out:
# ['Member', 'Normal']

# %%
print("Total number of unique values in the Customer type column: {}".format(len(df['Customer type'].unique().tolist())))
# Out:
# Total number of unique values in the Customer type column: 2

# %%
df['Gender'].unique().tolist()
# Out:
# ['Female', 'Male']

# %%
print("Total number of unique values in the Gender column: {}".format(len(df['Gender'].unique().tolist())))
# Out:
# Total number of unique values in the Gender column: 2

# %%
df['Product line'].unique().tolist()
# Out:
# ['Food and beverages',
#  'Fashion accessories',
#  'Electronic accessories',
#  'Sports and travel',
#  'Home and lifestyle',
#  'Health and beauty']

# %%
print("Total number of unique values in the Product line column: {}".format(len(df['Product line'].unique().tolist())))
# Out:
# Total number of unique values in the Product line column: 6

# %%
df['Date'].unique().tolist()
# Out:
# [1550620800000000000,
#  1549411200000000000,
#  1552089600000000000,
#  1547510400000000000,
#  1552262400000000000,
#  1551744000000000000,
#  1552608000000000000,
#  1549584000000000000,
#  1548374400000000000,
#  1551052800000000000,
#  1548633600000000000,
#  1547078400000000000,
#  1551571200000000000,
#  1547683200000000000,
#  1551225600000000000,
#  1549756800000000000,
#  1553212800000000000,
#  1551916800000000000,
#  1549152000000000000,
#  1550102400000000000,
#  1546819200000000000,
#  1548460800000000000,
#  1552348800000000000,
#  1553817600000000000,
#  1552953600000000000,
#  1549324800000000000,
#  1550188800000000000,
#  1547596800000000000,
#  1547942400000000000,
#  1550361600000000000,
#  1550275200000000000,
#  1551830400000000000,
#  1553299200000000000,
#  1546560000000000000,
#  1553904000000000000,
#  1553644800000000000,
#  1547856000000000000,
#  1547769600000000000,
#  1549843200000000000,
#  1553731200000000000,
#  1551484800000000000,
# ...

# %%
print("Total number of unique values in the Date column: {}".format(len(df['Date'].unique().tolist())))
# Out:
# Total number of unique values in the Date column: 89

# %%
df['Time'].unique().tolist()
# Out:
# [1675344420000000000,
#  1675361220000000000,
#  1675357380000000000,
#  1675354740000000000,
#  1675351800000000000,
#  1675334400000000000,
#  1675340400000000000,
#  1675351860000000000,
#  1675367280000000000,
#  1675366740000000000,
#  1675341780000000000,
#  1675349340000000000,
#  1675342860000000000,
#  1675363500000000000,
#  1675342980000000000,
#  1675360800000000000,
#  1675358640000000000,
#  1675352820000000000,
#  1675341900000000000,
#  1675348920000000000,
#  1675338540000000000,
#  1675345200000000000,
#  1675348500000000000,
#  1675350060000000000,
#  1675361820000000000,
#  1675367760000000000,
#  1675360500000000000,
#  1675339740000000000,
#  1675333500000000000,
#  1675361640000000000,
#  1675361940000000000,
#  1675337520000000000,
#  1675341840000000000,
#  1675340940000000000,
#  1675351560000000000,
#  1675370280000000000,
#  1675358760000000000,
#  1675349820000000000,
#  1675336500000000000,
#  1675343880000000000,
#  1675362960000000000,
# ...

# %%
print("Total number of unique values in the Time column: {}".format(len(df['Time'].unique().tolist())))
# Out:
# Total number of unique values in the Time column: 506

# %%
df['Payment'].unique().tolist()
# Out:
# ['Card', 'Epay', 'Cash']

# %%
print("Total number of unique values in the Payment column: {}".format(len(df['Payment'].unique().tolist())))
# Out:
# Total number of unique values in the Payment column: 3

# %%
df['Invoice ID'].value_counts()
# Out:
# 692-92-5582    1
# 849-09-3807    1
# 324-92-3863    1
# 593-08-5916    1
# 558-60-5016    1
#               ..
# 365-64-0515    1
# 252-56-2699    1
# 829-34-3910    1
# 656-95-9349    1
# 233-67-5758    1
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# 2019-02-07    20
# 2019-02-15    19
# 2019-03-14    18
# 2019-01-08    18
# 2019-03-02    18
#               ..
# 2019-02-28     6
# 2019-03-17     6
# 2019-03-21     6
# 2019-02-21     6
# 2019-01-04     6
# Name: Date, Length: 89, dtype: int64

# %%
df['Time'].value_counts()
# Out:
# 2023-02-02 14:42:00    7
# 2023-02-02 19:48:00    7
# 2023-02-02 17:38:00    6
# 2023-02-02 19:20:00    5
# 2023-02-02 19:39:00    5
#                       ..
# 2023-02-02 16:20:00    1
# 2023-02-02 16:31:00    1
# 2023-02-02 11:19:00    1
# 2023-02-02 16:55:00    1
# 2023-02-02 19:12:00    1
# Name: Time, Length: 506, dtype: int64

# %%
df['Payment'].value_counts()
# Out:
# Epay    345
# Cash    344
# Card    311
# Name: Payment, dtype: int64

# %% [markdown]
# ## Aggregation with GroupBy

# %%
City_grp = df.groupby('City').agg({'Unit price': ['sum', 'mean']})

# %%
City_grp
# Out:
#               Unit price
#                      sum          mean
# City
# Abuja          6652396.8  20037.339759
# Lagos          6705176.4  19721.107059
# Port Harcourt  6684393.6  20379.248780

# %%
df.groupby('City').agg({'gross income': 'max'})
# Out:
#                gross income
# City
# Abuja               17528.4
# Lagos               17816.4
# Port Harcourt       17874.0

# %%
df.groupby('City').agg({'gross income': 'sum'})
# Out:
#                gross income
# City
# Abuja            1820531.52
# Lagos            1820577.78
# Port Harcourt    1895463.54

# %%
City_grp = df.groupby('City').agg({'Unit price': ['sum', 'mean']})

# %%
City_grp
# Out:
#               Unit price
#                      sum          mean
# City
# Abuja          6652396.8  20037.339759
# Lagos          6705176.4  19721.107059
# Port Harcourt  6684393.6  20379.248780

# %%
df.groupby('City').agg({'Quantity': 'max'})
# Out:
#                Quantity
# City
# Abuja                10
# Lagos                10
# Port Harcourt        10

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(x='City', data= df).set_title('Sales')
# Out:
# Text(0.5, 1.0, 'Sales')

# %%
sns.countplot(x='City',hue='Payment', saturation=1, data= df).set_title('Sales')
# Out:
# Text(0.5, 1.0, 'Sales')

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Day', 'Month', 'Year', 'Hour'],
#       dtype='object')

# %%
sns.countplot(y='Product line', data=df).set_title('Product Line')
# Out:
# Text(0.5, 1.0, 'Product Line')

# %%
sns.countplot(y='Product line', hue='Payment', saturation=1, data=df).set_title('Product Line')
# Out:
# Text(0.5, 1.0, 'Product Line')

# %%
sns.countplot(x='Payment', hue='Branch', data=df).set_title('Payment_Channel')
# Out:
# Text(0.5, 1.0, 'Payment_Channel')

# %%
sns.boxplot(x='Rating', y='Branch', data=df).set_title('Rating')
# Out:
# Text(0.5, 1.0, 'Rating')

# %% [markdown]
# #### Branch with the lowest rating is B(Abuja)

# %%
sns.catplot(x='Product line', y='Quantity', hue='Gender', aspect=4, data=df)

# %%
sns.catplot(x='Product line', y='Total', hue='Gender', aspect=4, data=df)

# %%
sns.catplot(x='Product line', y='Unit price', kind='point', aspect=3, data=df)

# %%
sns.catplot(x='Product line', y='Quantity', kind='point', aspect=3, data=df)

# %% [markdown]
# #### There is reduced quantity of fashion accessories, however, it is the  most expensive of all products. On the other hand, Electronic accessories has the highest quantity of all products but is the least expensive. People tend to spend more on fashion accessories irrespective of the price.

# %% [markdown]
# ## StandOut Section

# %%
df.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# Day                        0.057021 -0.043347 -0.002515 -0.002515 -0.002515
# Month                     -0.027387 -0.014524 -0.022301 -0.022301 -0.022301
# Year                            NaN       NaN       NaN       NaN       NaN
# ...

# %%
df.plot(x= 'Quantity', y= 'gross income', kind= 'scatter')
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='gross income'>

# %%
df.plot(x= 'Quantity', y= 'gross income', kind= 'line')
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
df.plot(x= 'Unit price', y= 'Quantity', kind= 'scatter')
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='Quantity'>

# %%
df.plot(x= 'cogs', y= 'gross income', kind= 'line')
# Out:
# <AxesSubplot:xlabel='cogs'>

# %%
df.plot(x= 'cogs', y= 'Tax 5%', kind= 'line')
# Out:
# <AxesSubplot:xlabel='cogs'>

# %% [markdown]
# #### Using the corr() method, the table above shows lots of numbers that represent how well the relationship is between two columns(variables).
# - There is a fair relationship between the quantity of goods sold and the gross income with a correlation coefficient of 0.705510, which means that as the number of products purchased by customers increases, the gross income will probably increase as well, as shown in the line and scatter plot above.
#
# - There is no relationship between the price of product(Unit price) and the number of products purchased by the customer with a correlation coefficient of 0.010778. In other words, the price of product is not affected by the quantity of goods purchased by the customer as seen in the scatter plot above.
#
# - There is a perfect linear relationship between the cost of goods sold and the gross income with a correlation coefficient of 1. This means that more income will always be generated as the  cost of goods sold is increased. as shown in the line plot above.
#
# - There is a perfect relationship between the tax fee for customer buying(Tax 5%) and the cost of goods sold with a correlation coefficient of 1. This simply means that the tax increases as the cost of goods sold is increased as displayed in the line plot above.

# %%
df.to_csv('Pandas_Project')
